# %%
pip install ollama pull mistral
# Out:
# Requirement already satisfied: ollama in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (0.4.1)
# Requirement already satisfied: pull in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (0.0.1)
# Requirement already satisfied: mistral in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (19.0.0)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from ollama) (0.27.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from ollama) (2.10.1)
# Requirement already satisfied: Jinja2>=2.10 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.1.2)
# Requirement already satisfied: PyJWT>=1.5 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (2.4.0)
# Requirement already satisfied: PyYAML>=5.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.0)
# Requirement already satisfied: SQLAlchemy>=1.2.5 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (1.4.39)
# Requirement already satisfied: WSME>=0.8.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (0.12.1)
# Requirement already satisfied: alembic>=0.9.6 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (1.14.0)
# Requirement already satisfied: cachetools>=2.0.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.5.0)
# Requirement already satisfied: croniter>=0.3.4 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.0.1)
# Requirement already satisfied: dogpile.cache>=0.6.2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (1.3.3)
# Requirement already satisfied: eventlet>=0.26.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (0.38.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (4.17.3)
# Requirement already satisfied: keystonemiddleware>=4.18.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (10.8.0)
# Requirement already satisfied: kombu!=4.0.2,>=4.6.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.4.2)
# Requirement already satisfied: mistral-lib>=2.3.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.0.0)
# Requirement already satisfied: networkx>=2.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.1)
# Requirement already satisfied: oslo.concurrency>=3.26.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.2.0)
# Requirement already satisfied: oslo.config>=6.8.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (9.7.0)
# Requirement already satisfied: oslo.context>=2.22.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.7.0)
# Requirement already satisfied: oslo.db>=4.40.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (17.0.0)
# Requirement already satisfied: oslo.i18n>=3.15.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.5.0)
# Requirement already satisfied: oslo.log>=3.36.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.2.0)
# Requirement already satisfied: oslo.messaging>=14.1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (15.0.0)
# Requirement already satisfied: oslo.middleware>=3.31.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.3.0)
# Requirement already satisfied: oslo.policy>=3.6.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (4.5.0)
# Requirement already satisfied: oslo.serialization>=2.21.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.6.0)
# Requirement already satisfied: oslo.service>=2.1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.6.0)
# Requirement already satisfied: oslo.utils>=4.0.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (7.4.0)
# Requirement already satisfied: osprofiler>=1.4.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (4.2.0)
# Requirement already satisfied: paramiko>=2.4.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.1.0)
# Requirement already satisfied: pecan>=1.2.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (1.5.1)
# Requirement already satisfied: requests>=2.18.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (2.31.0)
# Requirement already satisfied: stevedore>=1.20.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (5.4.0)
# Requirement already satisfied: tenacity>=5.0.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (9.0.0)
# Requirement already satisfied: tooz>=1.58.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (6.3.0)
# Requirement already satisfied: yaql>=1.1.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from mistral) (3.0.0)
# Requirement already satisfied: Mako in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from alembic>=0.9.6->mistral) (1.3.6)
# Requirement already satisfied: typing-extensions>=4 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from alembic>=0.9.6->mistral) (4.12.2)
# Requirement already satisfied: python-dateutil in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from croniter>=0.3.4->mistral) (2.8.2)
# Requirement already satisfied: pytz>2021.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from croniter>=0.3.4->mistral) (2023.3.post1)
# Requirement already satisfied: decorator>=4.0.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from dogpile.cache>=0.6.2->mistral) (5.1.1)
# Requirement already satisfied: dnspython>=1.15.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from eventlet>=0.26.0->mistral) (2.7.0)
# Requirement already satisfied: greenlet>=1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from eventlet>=0.26.0->mistral) (2.0.1)
# Requirement already satisfied: anyio in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.5.0)
# Requirement already satisfied: certifi in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (2023.11.17)
# Requirement already satisfied: httpcore==1.* in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.0.7)
# Requirement already satisfied: idna in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (3.4)
# Requirement already satisfied: sniffio in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpx<0.28.0,>=0.27.0->ollama) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama) (0.14.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from Jinja2>=2.10->mistral) (2.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.2.0->mistral) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from jsonschema>=3.2.0->mistral) (0.18.0)
# Requirement already satisfied: WebOb>=1.7.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystonemiddleware>=4.18.0->mistral) (1.8.9)
# Requirement already satisfied: keystoneauth1>=3.12.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystonemiddleware>=4.18.0->mistral) (5.9.0)
# Requirement already satisfied: oslo.cache>=1.26.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystonemiddleware>=4.18.0->mistral) (3.9.0)
# Requirement already satisfied: pycadf>=1.1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystonemiddleware>=4.18.0->mistral) (4.0.0)
# Requirement already satisfied: python-keystoneclient>=3.20.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystonemiddleware>=4.18.0->mistral) (5.5.0)
# Requirement already satisfied: amqp<6.0.0,>=5.1.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from kombu!=4.0.2,>=4.6.1->mistral) (5.3.1)
# Requirement already satisfied: vine==5.1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from kombu!=4.0.2,>=4.6.1->mistral) (5.1.0)
# Requirement already satisfied: tzdata in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from kombu!=4.0.2,>=4.6.1->mistral) (2023.3)
# Requirement already satisfied: fasteners>=0.7.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.concurrency>=3.26.0->mistral) (0.19)
# Requirement already satisfied: debtcollector>=1.2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.config>=6.8.0->mistral) (3.0.0)
# Requirement already satisfied: netaddr>=0.7.18 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.config>=6.8.0->mistral) (1.3.0)
# Requirement already satisfied: rfc3986>=1.2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.config>=6.8.0->mistral) (2.0.0)
# Requirement already satisfied: testresources>=2.0.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.db>=4.40.0->mistral) (2.0.1)
# Requirement already satisfied: testscenarios>=0.4 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.db>=4.40.0->mistral) (0.5.0)
# Requirement already satisfied: futurist>=1.2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.messaging>=14.1.0->mistral) (3.0.0)
# Requirement already satisfied: oslo.metrics>=0.2.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.messaging>=14.1.0->mistral) (0.10.0)
# Requirement already satisfied: bcrypt>=3.1.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.middleware>=3.31.0->mistral) (4.2.1)
# Requirement already satisfied: statsd>=3.2.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.middleware>=3.31.0->mistral) (4.0.1)
# Requirement already satisfied: msgpack>=0.5.2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.serialization>=2.21.1->mistral) (1.0.3)
# Requirement already satisfied: Paste>=2.0.2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.service>=2.1.0->mistral) (3.10.1)
# Requirement already satisfied: PasteDeploy>=1.5.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.service>=2.1.0->mistral) (3.1.0)
# Requirement already satisfied: Routes>=2.3.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.service>=2.1.0->mistral) (2.5.1)
# Requirement already satisfied: Yappi>=1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.service>=2.1.0->mistral) (1.6.10)
# Requirement already satisfied: iso8601>=0.1.11 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.utils>=4.0.0->mistral) (2.1.0)
# Requirement already satisfied: packaging>=20.4 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.utils>=4.0.0->mistral) (24.2)
# Requirement already satisfied: psutil>=3.2.2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.utils>=4.0.0->mistral) (5.9.0)
# Requirement already satisfied: pyparsing>=2.1.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.utils>=4.0.0->mistral) (3.0.9)
# Requirement already satisfied: PrettyTable>=0.7.2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from osprofiler>=1.4.0->mistral) (3.12.0)
# Requirement already satisfied: cryptography>=3.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from paramiko>=2.4.1->mistral) (41.0.3)
# Requirement already satisfied: pynacl>=1.5 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from paramiko>=2.4.1->mistral) (1.5.0)
# Requirement already satisfied: setuptools in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from pecan>=1.2.1->mistral) (68.0.0)
# Requirement already satisfied: logutils>=0.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from pecan>=1.2.1->mistral) (0.3.5)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.9.0->ollama) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from requests>=2.18.0->mistral) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from requests>=2.18.0->mistral) (1.26.16)
# Requirement already satisfied: voluptuous>=0.8.9 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from tooz>=1.58.0->mistral) (0.15.2)
# Requirement already satisfied: simplegeneric in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from WSME>=0.8.0->mistral) (0.8.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from WSME>=0.8.0->mistral) (6.0.0)
# Requirement already satisfied: ply in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from yaql>=1.1.3->mistral) (3.11)
# Requirement already satisfied: cffi>=1.12 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from cryptography>=3.3->paramiko>=2.4.1->mistral) (1.15.1)
# Requirement already satisfied: wrapt>=1.7.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from debtcollector>=1.2.0->oslo.config>=6.8.0->mistral) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from importlib-metadata>=4.4->WSME>=0.8.0->mistral) (3.11.0)
# Requirement already satisfied: os-service-types>=1.2.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from keystoneauth1>=3.12.0->keystonemiddleware>=4.18.0->mistral) (1.7.0)
# Requirement already satisfied: prometheus-client>=0.6.0 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from oslo.metrics>=0.2.1->oslo.messaging>=14.1.0->mistral) (0.14.1)
# Requirement already satisfied: wcwidth in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from PrettyTable>=0.7.2->osprofiler>=1.4.0->mistral) (0.2.5)
# Requirement already satisfied: six>=1.5 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from python-dateutil->croniter>=0.3.4->mistral) (1.16.0)
# Requirement already satisfied: repoze.lru>=0.3 in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from Routes>=2.3.1->oslo.service>=2.1.0->mistral) (0.7)
# Requirement already satisfied: testtools in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from testscenarios>=0.4->oslo.db>=4.40.0->mistral) (2.7.2)
# Requirement already satisfied: pycparser in /Users/derinsparkles/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=3.3->paramiko>=2.4.1->mistral) (2.21)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Cell 1: Setup and Imports
from langchain_ollama import OllamaLLM
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
import json
import time

# Initialize LLM
llm = OllamaLLM(model="mistral", temperature=0.1)
print("LLM initialized with Mistral model")
# Out:
# LLM initialized with Mistral model

# %%
# Cell 2: Load and examine input data
start_time = time.time()

with open('client_data.json', 'r') as file:
    client_data = json.load(file)

test_json = client_data['results'][0]  # First record

print("Sample input data structure:")
print(f"Number of fields: {len(test_json.keys())}")
print("Fields present:", list(test_json.keys()))
print("\nSample input data:")
print(json.dumps(test_json, indent=2))
print(f"\nInput data size: {len(str(test_json))} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Sample input data structure:
# Number of fields: 38
# Fields present: ['id', 'fullName', 'name', 'code', 'fullAddress', 'locationName', 'title', 'forename', 'surname', 'gender', 'addressLine1', 'addressLine2', 'addressLine3', 'addressLine4', 'addressLine5', 'postCode', 'telephone', 'mobile', 'email', 'fax', 'web', 'online', 'status', 'type', 'contractNumber', 'onlineGuid', 'defaultLocationId', 'serviceTypeId', 'regNumber', 'commissionFlatRate', 'commissionPercent', 'employmentStatus', 'timeSlot', 'taxNo', 'alerts', 'locationIds', 'skills', 'orderId']
#
# Sample input data:
# {
#   "id": 808656,
#   "fullName": "Ms. Mandy Thompson",
#   "name": "Mandy Thompson",
#   "code": "",
#   "fullAddress": "Flat 49\nStacey Junction, South Peter, Cambridgeshire, NG24 2PB, Northern Ireland",
#   "locationName": "Marshall Ltd",
#   "title": "Ms.",
#   "forename": "Mandy",
#   "surname": "Thompson",
#   "gender": "Female",
#   "addressLine1": "Flat 49\nStacey Junction",
#   "addressLine2": null,
#   "addressLine3": "",
#   "addressLine4": "",
#   "addressLine5": "",
#   "postCode": "NG24 2PB",
#   "telephone": "",
#   "mobile": "07533 808703",
#   "email": "louis.mitchell@example.org",
#   "fax": "",
#   "web": "",
#   "online": true,
#   "status": 1,
#   "type": "Owner",
#   "contractNumber": "",
#   "onlineGuid": "5c2e5024-a33f-34b0-9da5-6446d2e3e466",
#   "defaultLocationId": 932896,
#   "serviceTypeId": 1,
#   "regNumber": "",
#   "commissionFlatRate": 0,
#   "commissionPercent": 0,
#   "employmentStatus": "Owner",
#   "timeSlot": 0,
#   "taxNo": "",
#   "alerts": [],
#   "locationIds": [
#     932896
#   ],
#   "skills": [],
#   "orderId": 0
# }
#
# Input data size: 913 characters
# Time taken: 0.00 seconds

# %%
# Cell 3: Load and process schema
start_time = time.time()

with open('schema.sql', 'r') as file:
    schema_sql = file.read()

def extract_field_constraints(schema_sql):
    """Extract exact field names, types, and constraints"""
    constraints = {}
    
    # Find CREATE TABLE statements
    tables = schema_sql.split('CREATE TABLE')
    for table in tables[1:]:  # Skip first empty split
        if '`' not in table:
            continue
            
        table_name = table.split('`')[1]
        field_lines = table.split('\n')
        
        fields = {}
        for line in field_lines:
            if '`' in line:
                # Extract field definition
                field_name = line.split('`')[1]
                field_def = line.strip()
                fields[field_name] = field_def
                
        constraints[table_name] = fields
    
    print(f"Extracted constraints for {len(constraints)} tables")
    return constraints

# Extract constraints
schema_constraints = extract_field_constraints(schema_sql)

print("\nSample constraints for first table:")
first_table = next(iter(schema_constraints))
print(f"Table: {first_table}")
print(json.dumps(schema_constraints[first_table], indent=2))
print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Extracted constraints for 47 tables
#
# Sample constraints for first table:
# Table: addresses
# {
#   "addresses": "`addresses` (",
#   "id": "`id` bigint PRIMARY KEY NOT NULL,",
#   "addressable_type": "`addressable_type` varchar(255) NOT NULL,",
#   "addressable_id": "`addressable_id` bigint NOT NULL,",
#   "address_line_1": "`address_line_1` varchar(255) DEFAULT null,",
#   "address_line_2": "`address_line_2` varchar(255) DEFAULT null,",
#   "address_line_3": "`address_line_3` varchar(255) DEFAULT null,",
#   "town_city": "`town_city` varchar(255) DEFAULT null,",
#   "state_county": "`state_county` varchar(255) DEFAULT null,",
#   "postcode_zipcode": "`postcode_zipcode` varchar(255) DEFAULT null,",
#   "country": "`country` varchar(255) DEFAULT null,",
#   "created_at": "`created_at` timestamp DEFAULT null,",
#   "updated_at": "`updated_at` timestamp DEFAULT null,",
#   "deleted_at": "`deleted_at` timestamp DEFAULT null"
# }
#
# Time taken: 0.01 seconds

# %%
# Cell 4: Initial Schema Analysis
start_time = time.time()

analysis_prompt = f"""Analyze these schema constraints and input JSON structure:

Schema Constraints:
{json.dumps(schema_constraints, indent=2)}

Input JSON:
{json.dumps(test_json, indent=2)}

Identify:
1. Which table fields match input fields
2. Required data type conversions
3. Any missing required fields

Return analysis in clear format."""

schema_analysis = llm.invoke(analysis_prompt)

print("Schema Analysis Results:")
print(schema_analysis)
print(f"\nTime taken: {time.time() - start_time:.2f} seconds")

# Save analysis for next steps
with open('schema_analysis.txt', 'w') as f:
    f.write(schema_analysis)
# Out:
# Schema Analysis Results:
# 1. Matching Input Fields with Table Fields:
#    - addressLine1: patient_details.addressLine1
#    - postCode: patient_details.postCode
#    - mobile: patient_details.mobile
#    - email: patient_details.email
#    - type: practices.type
#    - onlineGuid: roles.onlineGuid (Assuming the role is associated with the practice)
#    - defaultLocationId: locations.id (Assuming the location is associated with the practice)
#    - serviceTypeId: services.id (Assuming the service is associated with the practice)
#    - regNumber: practices.regNumber (If applicable, as it's not a standard field for all types of practices)
#    - commissionFlatRate: roles.commissionFlatRate (Assuming the role has commission settings)
#    - commissionPercent: roles.commissionPercent (Assuming the role has commission settings)
#    - employmentStatus: roles.employmentStatus (Assuming the employment status is associated with the user's role)
#
# 2. Required Data Type Conversions:
#    - None, as all input fields match the expected data types in the table.
#
# 3. Missing Required Fields:
#    - None, as all required fields seem to be present based on the provided data structure.
#
# Time taken: 116.25 seconds

# %%
# Cell 5: Transform First Record
start_time = time.time()

# Load saved analysis
with open('schema_analysis.txt', 'r') as f:
    saved_analysis = f.read()

transform_prompt = f"""Transform this JSON record using the schema analysis and constraints:

Schema Analysis:
{saved_analysis}

Schema Constraints:
{json.dumps(schema_constraints, indent=2)}

Input JSON:
{json.dumps(test_json, indent=2)}

Rules:
1. Only use field names from schema
2. Match data types exactly
3. Handle required fields
4. Return valid JSON only

Return transformed JSON that matches schema exactly."""

transformed_json = llm.invoke(transform_prompt)

print("Transformed Result:")
print(transformed_json)
print(f"\nTime taken: {time.time() - start_time:.2f} seconds")

# Save transformation result
with open('transformed.json', 'w') as f:
    f.write(transformed_json)
# Out:
# Transformed Result:
#  Here is the transformed JSON based on the rules provided:
#
# ```json
# {
#   "id": 808656,
#   "locationName": "Marshall Ltd",
#   "title": "Ms.",
#   "forename": "Mandy",
#   "surname": "Thompson",
#   "gender": "Female",
#   "addressLine1": "Flat 49\nStacey Junction, South Peter, Cambridgeshire, NG24 2PB, Northern Ireland"foreign key (`practice_id`) references `practices (`id`);",
#   "telephone": "",
#   "mobile": "075333808703",
#   "email": "louis.mitchell@exampleorg",
#   "fax": "",
#   "web": "",
#   "online": true,
#   "status": 1,
#   "type": "Owner",
#   "contractNumber": "",
#   "onlineGuid": "5c2e5024-a3f3b09da5-6446d2e346d2e3e34-a33b09da5-646d2e346d2e3foreign key (`practice_id) references `practices`(`id`);"
# }
# ```
#
# This JSON is transformed to match the schema exactly, but it seems there are some syntax errors in the provided schema. Please review and correct them for proper functionality.
#
# Time taken: 120.26 seconds

# %%
start_time = time.time()
transform_prompt = f"""Correct this transformed JSON record using the schema analysis and constraints, changing field names and data types as needed:

Schema Analysis:
{saved_analysis}

Schema Constraints:
{json.dumps(schema_constraints, indent=2)}

Input JSON:
{json.dumps(test_json, indent=2)}

Rules:
1. Change the keys/field names in input to the befitting field name of the schema
2. Match data types in input to data type in schema exactly
3. Handle required fields
4. Return valid JSON only

Return transformed JSON that matches schema exactly."""

transformed_json = llm.invoke(transform_prompt)

print("Transformed Result:")
print(transformed_json)
print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Transformed Result:
#  Here is the transformed JSON based on the given rules:
#
# ```json
# {
#   "practitioner_id": 808656,
#   "fullName": "Ms. Mandy Thompson",
#   "name": "Mandy Thompson",
#   "code": "",
#   "fullAddress": "Flat 49\nStacey Junction, South Peter, Cambridgeshire, NG24 2PB, Northern Ireland` FOREIGN KEY (`parent_service_id`) REFERENCES parent_services`(id)`,
#   "locationName": "Marshall Ltd",
#   "title": "Ms.",
#   "forename": "Mandy",
#   "surname": "Thompson",
#   "gender": "Female",
#   "addressLine1": "Flat 49\nStacey Junction, South Peter, Cambridgeshire, NG24 2PB, Northern Ireland` FOREIGN KEY (user_id) REFERENCES users`(id`);",
#   "postCode": "NG24 2PB",
#   "telephone": "",
#   "mobile": "07533 808703",
#   "email": "louis.mitchell@exampleorg",
#   "fax": "",
#   "web": "",
#   "online": true,
#   "status": 1,
#   "type": "Owner",
#   "contractNumber": "",
#   "onlineGuid": "5c2e5024-a33f-34b0-9da5-6446d2e3e466",
#   "defaultLocationId": 932896,
#   "serviceTypeId": 1,
#   "regNumber": "",
#   "commissionFlatRate": 0,
#   "commissionPercent": 0,
#   "employmentStatus": "Owner",
#   "timeSlot": 0,
#   "taxNo": "",
#   "alerts": [],
#   "locationIds": [932896],
#   "skills": [],
#   "orderId": 0
# }
# ```
#
# Time taken: 129.19 seconds

# %%
# Cell 1: Imports and basic setup
from langchain_ollama import OllamaLLM
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma
from langchain.text_splitter import RecursiveCharacterTextSplitter
import json
import time
import os
from datetime import datetime  # Added this import
from tqdm.notebook import tqdm

# Initialize LLM with Mistral
llm = OllamaLLM(model="mistral", temperature=0.1)
print("LLM initialized with Mistral model")
# Out:
# LLM initialized with Mistral model

# %%
# Cell 2: Load and examine client data
start_time = time.time()

with open('client_data.json', 'r') as file:
    client_data = json.load(file)

test_json = client_data['results'][0]  # First record

print("Sample input data structure:")
print(f"Number of fields: {len(test_json.keys())}")
print("Fields present:", list(test_json.keys()))
print("\nSample input data:")
print(json.dumps(test_json, indent=2))
print(f"\nInput data size: {len(str(test_json))} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Sample input data structure:
# Number of fields: 38
# Fields present: ['id', 'fullName', 'name', 'code', 'fullAddress', 'locationName', 'title', 'forename', 'surname', 'gender', 'addressLine1', 'addressLine2', 'addressLine3', 'addressLine4', 'addressLine5', 'postCode', 'telephone', 'mobile', 'email', 'fax', 'web', 'online', 'status', 'type', 'contractNumber', 'onlineGuid', 'defaultLocationId', 'serviceTypeId', 'regNumber', 'commissionFlatRate', 'commissionPercent', 'employmentStatus', 'timeSlot', 'taxNo', 'alerts', 'locationIds', 'skills', 'orderId']
#
# Sample input data:
# {
#   "id": 808656,
#   "fullName": "Ms. Mandy Thompson",
#   "name": "Mandy Thompson",
#   "code": "",
#   "fullAddress": "Flat 49\nStacey Junction, South Peter, Cambridgeshire, NG24 2PB, Northern Ireland",
#   "locationName": "Marshall Ltd",
#   "title": "Ms.",
#   "forename": "Mandy",
#   "surname": "Thompson",
#   "gender": "Female",
#   "addressLine1": "Flat 49\nStacey Junction",
#   "addressLine2": null,
#   "addressLine3": "",
#   "addressLine4": "",
#   "addressLine5": "",
#   "postCode": "NG24 2PB",
#   "telephone": "",
#   "mobile": "07533 808703",
#   "email": "louis.mitchell@example.org",
#   "fax": "",
#   "web": "",
#   "online": true,
#   "status": 1,
#   "type": "Owner",
#   "contractNumber": "",
#   "onlineGuid": "5c2e5024-a33f-34b0-9da5-6446d2e3e466",
#   "defaultLocationId": 932896,
#   "serviceTypeId": 1,
#   "regNumber": "",
#   "commissionFlatRate": 0,
#   "commissionPercent": 0,
#   "employmentStatus": "Owner",
#   "timeSlot": 0,
#   "taxNo": "",
#   "alerts": [],
#   "locationIds": [
#     932896
#   ],
#   "skills": [],
#   "orderId": 0
# }
#
# Input data size: 913 characters
# Time taken: 0.00 seconds

# %%
# Cell 3: Process schema into chunks
start_time = time.time()

# Load schema
with open('schema.sql', 'r') as file:
    schema_sql = file.read()

print("Schema statistics:")
print(f"Original schema length: {len(schema_sql)} characters")
print(f"Number of lines: {len(schema_sql.splitlines())}")

# Split into chunks - Modified to preserve CREATE TABLE statements
splitter = RecursiveCharacterTextSplitter(
    separators=["CREATE TABLE", "\n", " "],  # List of separators, prioritizing CREATE TABLE
    chunk_size=1000,          # Increased to keep full definitions
    chunk_overlap=0           # Removed overlap since we want complete statements
)

chunks = splitter.split_text(schema_sql)

print(f"\nChunking results:")
print(f"Number of chunks created: {len(chunks)}")
print(f"Average chunk size: {sum(len(c) for c in chunks)/len(chunks):.0f} characters")
print("\nSample chunk:")
print(chunks[0])

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Schema statistics:
# Original schema length: 26647 characters
# Number of lines: 718
#
# Chunking results:
# Number of chunks created: 34
# Average chunk size: 782 characters
#
# Sample chunk:
# CREATE TABLE `addresses` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `addressable_type` varchar(255) NOT NULL,
#   `addressable_id` bigint NOT NULL,
#   `address_line_1` varchar(255) DEFAULT null,
#   `address_line_2` varchar(255) DEFAULT null,
#   `address_line_3` varchar(255) DEFAULT null,
#   `town_city` varchar(255) DEFAULT null,
#   `state_county` varchar(255) DEFAULT null,
#   `postcode_zipcode` varchar(255) DEFAULT null,
#   `country` varchar(255) DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
#
# Time taken: 0.00 seconds

# %%
SUMMARIES_FILE = 'schema_summaries.json'
import os
def load_saved_summaries():
    """Try to load previously saved summaries"""
    if os.path.exists(SUMMARIES_FILE):
        with open(SUMMARIES_FILE, 'r') as f:
            data = json.load(f)
            print(f"Loading saved summaries from {data['timestamp']}")
            return data['summaries']
    return None

def save_summaries(summaries):
    """Save summaries with timestamp"""
    data = {
        'summaries': summaries,
        'timestamp': datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    }
    with open(SUMMARIES_FILE, 'w') as f:
        json.dump(data, f)
    print(f"\nSummaries saved to {SUMMARIES_FILE}")

# Try to load existing summaries first
start_time = time.time()
summaries = load_saved_summaries()

# If no saved summaries exist, generate them
if summaries is None:
    print("No saved summaries found. Generating new summaries...")
    summaries = []
    for i, chunk in enumerate(chunks):
        chunk_start = time.time()
        print(f"\nProcessing chunk {i+1}/{len(chunks)}...")
        
        prompt = f"""Summarize key requirements from this schema section:
        {chunk}
        
        Focus on:
        1. Field names and types
        2. Required vs optional fields
        3. Data format requirements
        4. Relationships between tables
        
        Provide a concise, structured summary."""
        
        summary = llm.invoke(prompt)
        summaries.append(summary)
        
        print(f"Chunk {i+1} processing time: {time.time() - chunk_start:.2f} seconds")
        print(f"Summary length: {len(summary)} characters")
        
        # Save progress after each chunk (in case of interruption)
        save_summaries(summaries)

else:
    print(f"Loaded {len(summaries)} existing summaries")

print("\nSample summary:")
print(summaries[0])
print(f"\nTotal time: {time.time() - start_time:.2f} seconds")
# Out:
# Loading saved summaries from 2024-11-29 02:26:31
# Loaded 34 existing summaries
#
# Sample summary:
# 1. Field Names and Types:
#    - `id`: bigint (Primary Key)
#    - `addressable_type`: varchar(255)
#    - `addressable_id`: bigint
#    - `address_line_1`, `address_line_2`, `address_line_3`: varchar(255) (optional)
#    - `town_city`: varchar(255)
#    - `state_county`: varchar(255)
#    - `postcode_zipcode`: varchar(255)
#    - `country`: varchar(255)
#    - `created_at`, `updated_at`, `deleted_at`: timestamp
#
# 2. Required vs Optional Fields:
#    - `id`, `addressable_type`, `addressable_id` are required.
#    - The remaining fields are optional, as they have a default value of null.
#
# 3. Data Format Requirements:
#    - All string fields (address_line_1, address_line_2, address_line_3, town_city, state_county, postcode_zipcode, country) have a maximum length of 255 characters.
#    - Timestamp fields (created_at, updated_at, deleted_at) store date and time information.
#
# 4. Relationships between Tables:
#    The `addresses` table does not explicitly define any relationships with other tables. However, the presence of `addressable_type` and `addressable_id` fields suggests that this table is likely related to another table through a many-to-one or one-to-many relationship. The specific nature of this relationship would need to be defined in the schema for the related table.
#
# Total time: 0.00 seconds

# %%
# Cell 5: Initialize vector store
start_time = time.time()

print("Initializing embeddings model...")
embeddings = HuggingFaceEmbeddings(
    model_name="all-MiniLM-L6-v2",
    model_kwargs={'device': 'cpu'}
)

# Combine chunks and summaries
texts = chunks + summaries
metadata = ([{"type": "chunk", "index": i} for i in range(len(chunks))] + 
           [{"type": "summary", "index": i} for i in range(len(summaries))])

print(f"\nPreparing vector store:")
print(f"Total texts to embed: {len(texts)}")
print(f"Chunks: {len(chunks)}, Summaries: {len(summaries)}")

vector_store = Chroma(embedding_function=embeddings)
vector_store.add_texts(texts=texts, metadatas=metadata)

print(f"Vector store initialized")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Initializing embeddings model...
# /var/folders/j1/ls8xpc1d53b27n6bxmqzdfgm0000gn/T/ipykernel_4412/1374878831.py:5: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embeddings = HuggingFaceEmbeddings(
# Preparing vector store:
# Total texts to embed: 68
# Chunks: 34, Summaries: 34
# /var/folders/j1/ls8xpc1d53b27n6bxmqzdfgm0000gn/T/ipykernel_4412/1374878831.py:19: LangChainDeprecationWarning: The class `Chroma` was deprecated in LangChain 0.2.9 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-chroma package and should be used instead. To use it run `pip install -U :class:`~langchain-chroma` and import as `from :class:`~langchain_chroma import Chroma``.
#   vector_store = Chroma(embedding_function=embeddings)
# Vector store initialized
# Time taken: 7.33 seconds

# %%
# Cell 6: Find relevant schema parts
start_time = time.time()

print("Searching for relevant schema parts...")
# Search for relevant chunks
relevant_chunks = vector_store.similarity_search(
    json.dumps(test_json),
    k=10,  # Get potential matches
    filter={"type": "chunk"}
)

# Verify chunks are actual tables from schema by checking table existence
valid_chunks = []
# print(relevant_chunks[0].page_content)
for chunk in relevant_chunks:
    # Only keep chunks that have complete CREATE TABLE statements
    if ('CREATE TABLE' in chunk.page_content 
        and chunk.page_content.strip().startswith('CREATE TABLE')
        and ');' in chunk.page_content):
        table_name = chunk.page_content.split('`')[1]  # Get table name between backticks
        valid_chunks.append(chunk)
print(valid_chunks[0].page_content)
print(f"\nFound {len(valid_chunks)} relevant chunks")
print("\nMost relevant schema chunks:")
valid_chunk_list = ""
for i, doc in enumerate(valid_chunks, 1):
    print(f"\nChunk {i}:")
    print(doc.page_content)
    valid_chunk_list = valid_chunk_list + '\n\n' +  doc.page_content
    print(f"Chunk {i} length: {len(doc.page_content)} characters")

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Searching for relevant schema parts...
# CREATE TABLE `practices` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `email` varchar(255) DEFAULT null,
#   `booking_portal_active` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_reminders_enabled` tinyint(1) NOT NULL DEFAULT '1',
#   `sms_enabled` tinyint(1) NOT NULL DEFAULT '0',
#   `sms_from_name` varchar(255) DEFAULT null,
#   `connected_stripe_account_id` varchar(255) DEFAULT null,
#   `stripe_id` varchar(255) DEFAULT null,
#   `rehabmypatient_api_key` text,
#   `mailerlite_api_key` text,
#   `pm_type` varchar(255) DEFAULT null,
#   `pm_last_four` varchar(4) DEFAULT null,
#   `trial_ends_at` timestamp DEFAULT null,
#   `timezone` varchar(255) NOT NULL DEFAULT 'Europe/London',
#   `currency` varchar(255) NOT NULL DEFAULT 'GBP',
#   `disable_notifications` tinyint NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
#
# Found 10 relevant chunks
#
# Most relevant schema chunks:
#
# Chunk 1:
# CREATE TABLE `practices` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `email` varchar(255) DEFAULT null,
#   `booking_portal_active` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_reminders_enabled` tinyint(1) NOT NULL DEFAULT '1',
#   `sms_enabled` tinyint(1) NOT NULL DEFAULT '0',
#   `sms_from_name` varchar(255) DEFAULT null,
#   `connected_stripe_account_id` varchar(255) DEFAULT null,
#   `stripe_id` varchar(255) DEFAULT null,
#   `rehabmypatient_api_key` text,
#   `mailerlite_api_key` text,
#   `pm_type` varchar(255) DEFAULT null,
#   `pm_last_four` varchar(4) DEFAULT null,
#   `trial_ends_at` timestamp DEFAULT null,
#   `timezone` varchar(255) NOT NULL DEFAULT 'Europe/London',
#   `currency` varchar(255) NOT NULL DEFAULT 'GBP',
#   `disable_notifications` tinyint NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
# Chunk 1 length: 954 characters
#
# Chunk 2:
# CREATE TABLE `patient_details` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `user_id` bigint NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `secondary_phone_number` varchar(255) DEFAULT null,
#   `gender` varchar(255) DEFAULT null,
#   `date_of_birth` datetime DEFAULT null,
#   `email_enabled` tinyint(1) NOT NULL DEFAULT '0',
#   `sms_enabled` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_reminders_enabled` tinyint(1) NOT NULL DEFAULT '1',
#   `referral_source` ENUM ('social_media', 'website', 'word_of_mouth', 'advert', 'google', 'other') DEFAULT null,
#   `cliniko_id` text,
#   `additional_fields` json DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `rehabmypatient_synced_at` datetime DEFAULT null,
#   `medical_alerts` json DEFAULT null
# );
# Chunk 2 length: 821 characters
#
# Chunk 3:
# CREATE TABLE `locations` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `practice_id` bigint NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `website` varchar(255) DEFAULT null,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `auto_email_form` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_portal_payments_active` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_portal_description` text,
#   `booking_portal_policy_excerpt` text,
#   `booking_portal_policy_link` varchar(255) DEFAULT null,
#   `booking_portal_gdpr_active` tinyint(1) NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
# Chunk 3 length: 786 characters
#
# Chunk 4:
# CREATE TABLE `addresses` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `addressable_type` varchar(255) NOT NULL,
#   `addressable_id` bigint NOT NULL,
#   `address_line_1` varchar(255) DEFAULT null,
#   `address_line_2` varchar(255) DEFAULT null,
#   `address_line_3` varchar(255) DEFAULT null,
#   `town_city` varchar(255) DEFAULT null,
#   `state_county` varchar(255) DEFAULT null,
#   `postcode_zipcode` varchar(255) DEFAULT null,
#   `country` varchar(255) DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
# Chunk 4 length: 571 characters
#
# Chunk 5:
# CREATE TABLE `services` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `parent_service_id` bigint NOT NULL,
#   `appointment_form_id` bigint DEFAULT null,
#   `service_information_link` int DEFAULT null,
#   `send_form_email` tinyint(1) DEFAULT null,
#   `name` varchar(255) NOT NULL,
#   `description` text,
#   `time_required_minutes` int DEFAULT null,
#   `start_minutes_past_hour` int DEFAULT null,
#   `price` int DEFAULT null,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `color` varchar(255) DEFAULT '#08BA98',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `category_id` bigint DEFAULT null,
#   `schedule_type` int DEFAULT null,
#   `buffer_time` int DEFAULT '0',
#   `cliniko_id` text
# );
# Chunk 5 length: 760 characters
#
# Chunk 6:
# CREATE TABLE `users` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `title` ENUM ('Mr', 'Mrs', 'Miss', 'Ms', 'Mx', 'Sir', 'Dr', 'Lady', 'Lord', 'Master', 'Other') DEFAULT null,
#   `first_name` varchar(255) NOT NULL,
#   `last_name` varchar(255) NOT NULL,
#   `password` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `practice_id` bigint DEFAULT null,
#   `email_verified_at` timestamp DEFAULT null,
#   `remember_token` varchar(100) DEFAULT null,
#   `notes` text,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `stripe_id` varchar(255) DEFAULT null,
#   `pm_type` varchar(255) DEFAULT null,
#   `pm_last_four` varchar(4) DEFAULT null,
#   `trial_ends_at` timestamp DEFAULT null,
#   `discounted` tinyint(1) DEFAULT null,
#   `privacy_policy_agreed_at` timestamp DEFAULT null,
#   `terms_conditions_agreed_at` timestamp DEFAULT null,
#   `cliniko_id` text,
#   `imported_id` text,
#   `last_location` bigint DEFAULT null
# );
# Chunk 6 length: 979 characters
#
# Chunk 7:
# CREATE TABLE `appointments` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `location_id` bigint DEFAULT null,
#   `number` varchar(255) DEFAULT null,
#   `patient_id` bigint NOT NULL,
#   `practitioner_id` bigint DEFAULT null,
#   `patient_case_id` bigint NOT NULL,
#   `status` ENUM ('draft', 'completed', 'Arrived', 'Did Not Arrive') NOT NULL DEFAULT 'draft',
#   `start_time` datetime NOT NULL,
#   `end_time` datetime NOT NULL,
#   `completed_at` datetime DEFAULT null,
#   `high_priority` tinyint(1) NOT NULL DEFAULT '0',
#   `made_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `details` text,
#   `scheduled_at` timestamp DEFAULT null,
#   `notified_at` timestamp DEFAULT null,
#   `started_at` timestamp DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `cliniko_id` text
# );
# Chunk 7 length: 876 characters
#
# Chunk 8:
# CREATE TABLE `patient_treatment_plans` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `practitioner_id` bigint NOT NULL,
#   `patient_id` bigint NOT NULL,
#   `location_id` bigint NOT NULL,
#   `appointment_id` bigint DEFAULT null,
#   `description` longtext,
#   `message` longtext,
#   `plans` json DEFAULT null,
#   `default_plan` bigint DEFAULT null,
#   `selected_plan` bigint DEFAULT null,
#   `patient_replay` longtext,
#   `status` varchar(255) DEFAULT null,
#   `selected_at` date DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null
# );
#
# CREATE TABLE `permissions` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `guard_name` varchar(255) NOT NULL,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null
# );
# Chunk 8 length: 846 characters
#
# Chunk 9:
# CREATE TABLE `service_user` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `user_id` bigint NOT NULL,
#   `service_id` bigint NOT NULL,
#   `appointment_form_id` bigint DEFAULT null,
#   `send_form_email` tinyint(1) DEFAULT null,
#   `time_required_minutes` int DEFAULT null,
#   `start_minutes_past_hour` int DEFAULT null,
#   `price` int DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `schedule_type` int DEFAULT null,
#   `buffer_time` int DEFAULT null
# );
#
# CREATE TABLE `sessions` (
#   `id` varchar(255) PRIMARY KEY NOT NULL,
#   `user_id` bigint DEFAULT null,
#   `ip_address` varchar(45) DEFAULT null,
#   `user_agent` text,
#   `payload` text NOT NULL,
#   `last_activity` int NOT NULL
# );
# Chunk 9 length: 748 characters
#
# Chunk 10:
# CREATE TABLE `practitioner_details` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `user_id` bigint NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `position` varchar(255) DEFAULT null,
#   `working_hours` json DEFAULT null,
#   `biography` text,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `cliniko_id` text
# );
#
# CREATE TABLE `roles` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `guard_name` varchar(255) NOT NULL,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null
# );
#
# CREATE TABLE `role_has_permissions` (
#   `permission_id` bigint NOT NULL,
#   `role_id` bigint NOT NULL,
#   PRIMARY KEY (`permission_id`, `role_id`)
# );
# Chunk 10 length: 805 characters
#
# Time taken: 0.04 seconds

# %%
# Cell 7: Analyze input data
start_time = time.time()

print("Starting input analysis...")
analysis_prompt = f"""Analyze this JSON input and identify:
1. Missing required fields based on schema
2. Fields needing format conversion (especially dates and names)
3. Data quality issues or inconsistencies

Input JSON: {json.dumps(test_json, indent=2)}

Schema Context: {valid_chunk_list}

Provide analysis in this format:
- Missing Fields: [list them]
- Format Conversions Needed: [field: required format]
- Quality Issues: [list any found]"""

analysis = llm.invoke(analysis_prompt)
print("\nInput Analysis Results:")
print(analysis)
print(f"\nAnalysis length: {len(analysis)} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting input analysis...
#
# Input Analysis Results:
#  In this schema, there are a few points to consider for improvement:
#
# - Missing Fields:
#   - `appointments` table lacks a foreign key reference to the `patients` table. It would be beneficial to have a patient_id field in the appointments table to link it with the patients table.
#   - The `services` table does not have a foreign key reference to the `users` table, which could be useful for associating services with specific practitioners.
#   - The `appointments` table lacks a foreign key reference to the `locations` table. It would be beneficial to have a location_id field in the appointments` table to link appointments with locations.
#   - The `patients` table does not have a foreign key reference to the `users` table, which could be useful for associating patients with specific practitioners.
#   - The `appointments` table lacks a foreign key reference to the `locations` table, which would help in linking appointments with locations.
#   - The `services` table does not have a foreign key reference to the `users` table, which could be useful for associating services with specific practitioners.
#   - The `appointments` table lacks a foreign key reference to the `patients` table, which would help in linking appointments with patients.
#
# - Format Conversions Needed:
#   - In the `users` table, the 'password' field should be hashed and salted before storing in the database for security reasons.
# - Quality Issues:
#   - The schema seems to lack a normalization of data types (e.g., using consistent data types across tables would improve readability and maintainability. For example, using `int` for ID fields instead of `varchar(255) in some tables.
#   - The schema could benefit from better naming conventions for consistency, such as prefixing table names with the application name (e.g., role_has_permissions` id` bigint PRIMARY KEY NOT NULL,
#   `role_id` bigint NOT NULL,
#   `permission_id` bigint NOT NULL,
#   `created_at` timestamp DEFAULT null,
#   - It would be beneficial to have a created_at field for tracking when the association was made.
# );
#
# - The schema lacks a table for storing patient case information, which could be useful for tracking medical history and progress over time.
# - The schema does not seem to include a table for storing appointment notes or comments, which would allow practitioners to leave notes on appointments.
# - The schema does not appear to have a table for storing patient feedback or reviews, which would help improve patient satisfaction and trust in the service.
# - The schema lacks a table for storing patient consents, which is crucial for maintaining privacy and compliance with regulations.
# - The schema does not seem to include a table for storing appointment reminders or scheduling, which could improve efficiency and reduce no-shows.
# - The schema does not appear to have a table for storing billing information, which would be necessary for managing payments and invoicing.
# - The schema lacks a table for storing patient demographics, such as age, gender, ethnicity, etc., which could help in analyzing patient populations and improving care.
# - The schema does not seem to include a table for storing insurance information, which would be necessary for managing payments and billing.
# - The schema lacks a table for storing appointment statistics, such as average wait times, no-show rates, etc., which could help in analyzing service performance and improving efficiency.
# - The schema does not appear to have a table for storing patient communication preferences, such as email or text message, which would improve patient engagement and satisfaction.
# - The schema lacks a table for storing patient education materials, such as articles, videos, etc., which could help in educating patients and improving health outcomes.
# - The schema does not seem to include a table for storing patient support resources, such as hotlines or support groups, which would be beneficial for patients seeking additional assistance.
# - The schema lacks a table for storing patient referrals, which would allow practitioners to easily refer patients to other providers or specialists.
# - The schema does not appear to have a table for storing practice policies and procedures, which could help in ensuring consistency and compliance across the practice.
# - The schema lacks a table for storing practice announcements or newsletters, which would help in keeping patients informed and engaged with the practice.
# - The schema does not seem to include a table for storing practice events, such as seminars or workshops, which could help in attracting new patients and improving community engagement.
# - The schema lacks a table for storing practice analytics, such as appointment volume, revenue, etc., which would help in managing the practice and making data-driven decisions.
# - The schema does not appear to have a table for storing practice marketing materials, such as ads or promotional content, which could help in attracting new patients.
# - The schema lacks a table for storing practice staff information, such as contact details, roles, etc., which would be useful for managing the practice and improving communication within the team.
# - The schema does not seem to include a table for storing practice financial data, such as income statements or balance sheets, which would be necessary for managing the practice's finances.
# - The schema lacks a table for storing practice compliance data, such as HIPAA audits or OSHA inspections, which would help in ensuring compliance with regulations and improving safety.
# - The schema does not appear to have a table for storing practice quality metrics, such as patient satisfaction scores or infection rates, which could help in improving the quality of care provided by the practice.
# - The schema lacks a table for storing practice accreditation data, such as Joint Commission surveys or CMS inspections, which would be necessary for maintaining accreditation and ensuring high-quality care.
# - The schema does not seem to include a table for storing practice performance metrics, such as appointment volume or revenue growth, which could help in tracking the practice's progress over time.
# - The schema lacks a table for storing practice benchmark data, such as industry averages for appointment volume or revenue growth, which would be useful for comparing the practice's performance to industry standards.
# - The schema does not appear to have a table for storing practice best practices, such as protocols for managing emergencies or guidelines for prescribing medications, which could help in improving care and reducing errors.
# - The schema lacks a table for storing practice research data, such as clinical trials or studies, which would be beneficial for advancing the field of medicine and improving patient outcomes.
# - The schema does not seem to include a table for storing practice collaboration opportunities, such as partnerships with other practices or research institutions, which could help in expanding the practice's reach and improving care.
# - The schema lacks a table for storing practice feedback from patients, staff, or external stakeholders, which would be useful for identifying areas for improvement and making data-driven decisions.
# - The schema does not appear to have a table for storing practice goals and objectives, which would help in setting and achieving practice-wide targets.
# - The schema lacks a table for storing practice milestones, such as the opening of new locations or the implementation of new technologies, which would be useful for tracking the practice's growth and development over time.
# - The schema does not seem to include a table for storing practice awards and recognitions, such as Best Practice Awards or Top Doctor lists, which would help in promoting the practice and attracting new patients.
# - The schema lacks a table for storing practice partnership agreements, such as joint ventures or strategic alliances, which would be necessary for managing partnerships and ensuring compliance with contractual obligations.
# - The schema does not appear to have a table for storing practice intellectual property, such as patents or trademarks, which would be crucial for protecting the practice's innovations and assets.
# - The schema lacks a table for storing practice legal documents, such as contracts or agreements, which would be necessary for managing legal matters and ensuring compliance with laws and regulations.
# - The schema does not seem to include a table for storing practice risk assessments, such as threat analyses or vulnerability assessments, which would help in identifying potential risks and taking appropriate measures to mitigate them.
# - The schema lacks a table for storing practice crisis management plans, such as emergency response plans or disaster recovery plans, which would be crucial for managing crises and ensuring the safety of patients, staff, and assets.
# - The schema does not appear to have a table for storing practice continuity of operations plans, such as business continuity plans or IT disaster recovery plans, which would help in maintaining operations during emergencies or disasters.
# - The schema lacks a table for storing practice communication protocols, such as incident reporting procedures or media relations guidelines, which would be useful for managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis response teams, such as incident management teams or emergency response teams, which would be crucial for managing crises effectively and efficiently.
# - The schema lacks a table for storing practice crisis training materials, such as drills or simulations, which would help in preparing staff for emergencies and improving their ability to respond effectively.
# - The schema does not appear to have a table for storing practice crisis lessons learned, such as after-action reports or root cause analyses, which would help in identifying areas for improvement and preventing future crises.
# - The schema lacks a table for storing practice crisis documentation, such as incident reports or meeting minutes, which would be necessary for tracking the progress of crises and ensuring compliance with regulations.
# - The schema does not seem to include a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not appear to have a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not seem to include a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not appear to have a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema lacks a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema lacks a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema does not appear to have a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema lacks a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema does not seem to include a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# ...
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis recovery plans, such as business continuity plans or IT disaster recovery plans, which would help in restoring operations after crises and minimizing downtime.
# - The schema lacks a table for storing practice crisis debriefings, such as post-incident reviews or lessons learned sessions, which would help in identifying areas for improvement and preventing future crises.
# - The schema does not appear to have a table for storing practice crisis after-action reports, such as root cause analyses or corrective action plans, which would help in identifying the causes of crises and taking appropriate measures to prevent them from recurring.
# - The schema lacks a table for storing practice crisis communication templates, such as press releases or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema does not seem to include a table for storing practice crisis communication guidelines, such as media relations policies or social media policies, which would help in managing communications during crises and ensuring compliance with regulations.
# - The schema does not appear to have a table for storing practice crisis communication logs, such as media inquiries or social media posts, which would help in managing communications during crises and ensuring consistency in messaging.
# - The schema lacks a table for storing practice crisis escalation procedures, such as escalation matrices or incident escalation protocols, which would help in ensuring that incidents are escalated appropriately and addressed effectively.
# - The schema does not seem to include a table for storing practice crisis
#
# Analysis length: 426891 characters
# Time taken: 6226.13 seconds

# %%
# Cell 8: Transform data
start_time = time.time()

print("Starting data transformation...")
transform_prompt = f"""Transform this JSON to match schema requirements:

Input JSON: {json.dumps(test_json, indent=2)}

Relevant Schema Context: {relevant_chunks[0].page_content}

Input JSON Analysis Results: {analysis}

Using the examples below as a guideline:
Example of Database Schema:
{{
  "id": "bigint",
  "title": "varchar(255)",
  "first_name": "varchar(255)",
  "last_name": "varchar(255)",
  "email": "varchar(255)",
  "practice_id": "bigint",
  "addressable_type": "varchar(255)",
  "addressable_id": "bigint",
  "address_line_1": "varchar(255)",
  "address_line_2": "varchar(255)",
  "town_city": "varchar(255)",
  "state_county": "varchar(255)",
  "postcode_zipcode": "varchar(255)",
  "country": "varchar(255)"
}}

Example of Desired Output:
{{
  "id": 123456,
  "title": "Dr",
  "first_name": "Jane",
  "last_name": "Smith",
  "email": null,
  "practice_id": null,
  "addressable_type": "User",
  "addressable_id": 123456,
  "address_line_1": "Unit 5",
  "address_line_2": "Main Street",
  "town_city": "Cambridge",
  "state_county": null,
  "postcode_zipcode": "CB1 1AA",
  "country": "England"
}}

Requirements:
1. Follow schema data types exactly
2. Handle missing fields appropriately (e.g., set to NULL)
3. Convert date formats to ISO (YYYY-MM-DD) and strings to varchar and integers to respective formats in schema
4. Split name fields if needed or other required fields as suggested in schema
5. Ensure all required fields are present
6. Remove fields not in schema
Return valid JSON only without any explanation."""

print("Sending transformation prompt...")
transformed_result = llm.invoke(transform_prompt)
print(f"Received response length: {len(transformed_result)} characters")

# Try to parse the result as JSON
try:
    transformed_data = json.loads(transformed_result)
    print("\nSuccessfully parsed transformed data:")
    print(json.dumps(transformed_data, indent=2))
    print(f"\nNumber of fields in output: {len(transformed_data.keys())}")
    print("Output fields:", list(transformed_data.keys()))
except json.JSONDecodeError as e:
    print("\nWarning: Output was not valid JSON")
    print("Error:", str(e))
    print("\nRaw output:")
    print(transformed_result)

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting data transformation...
# Sending transformation prompt...
# Received response length: 337 characters
#
# Successfully parsed transformed data:
# {
#   "id": 123,
#   "title": "Dr",
#   "first_name": "John",
#   "last_name": "Doe",
#   "email": null,
#   "practice_id": null,
#   "addressable_type": "User",
#   "addressable_id": 456,
#   "address_line_1": "123 Main St",
#   "address_line_2": null,
#   "town_city": "New York",
#   "state_county": "NY",
#   "postcode_zipcode": "10001",
#   "country": "USA"
# }
#
# Number of fields in output: 14
# Output fields: ['id', 'title', 'first_name', 'last_name', 'email', 'practice_id', 'addressable_type', 'addressable_id', 'address_line_1', 'address_line_2', 'town_city', 'state_county', 'postcode_zipcode', 'country']
#
# Time taken: 647.65 seconds

# %%
# Cell 2: Load and examine client data
start_time = time.time()

with open('client_data.json', 'r') as file:
    client_data = json.load(file)

test_json = client_data['results'][1]  # First record

print("Sample input data structure:")
print(f"Number of fields: {len(test_json.keys())}")
print("Fields present:", list(test_json.keys()))
print("\nSample input data:")
print(json.dumps(test_json, indent=2))
print(f"\nInput data size: {len(str(test_json))} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Sample input data structure:
# Number of fields: 38
# Fields present: ['id', 'fullName', 'name', 'code', 'fullAddress', 'locationName', 'title', 'forename', 'surname', 'gender', 'addressLine1', 'addressLine2', 'addressLine3', 'addressLine4', 'addressLine5', 'postCode', 'telephone', 'mobile', 'email', 'fax', 'web', 'online', 'status', 'type', 'contractNumber', 'onlineGuid', 'defaultLocationId', 'serviceTypeId', 'regNumber', 'commissionFlatRate', 'commissionPercent', 'employmentStatus', 'timeSlot', 'taxNo', 'alerts', 'locationIds', 'skills', 'orderId']
#
# Sample input data:
# {
#   "id": 678669,
#   "fullName": "Miss Lizzie Brown",
#   "name": "Lizzie Brown",
#   "code": "",
#   "fullAddress": "125 Jackson Ranch, -, Port Damienberg, Lancashire, TS24 7QA, Scotland",
#   "locationName": "Morris Ltd",
#   "title": "Miss",
#   "forename": "Lizzie",
#   "surname": "Brown",
#   "gender": "Male",
#   "addressLine1": "125 Jackson Ranch",
#   "addressLine2": "-",
#   "addressLine3": "",
#   "addressLine4": "",
#   "addressLine5": "",
#   "postCode": "TS24 7QA",
#   "telephone": "",
#   "mobile": "07608 506942",
#   "email": "uhughes@example.net",
#   "fax": "",
#   "web": "",
#   "online": true,
#   "status": 1,
#   "type": "Acupuncturist",
#   "contractNumber": "",
#   "onlineGuid": "1a3f38ac-c9d7-32a0-a89c-db6bb29b85d6",
#   "defaultLocationId": 771115,
#   "serviceTypeId": 1,
#   "regNumber": "",
#   "commissionFlatRate": 0,
#   "commissionPercent": 0,
#   "employmentStatus": "Acupuncturist",
#   "timeSlot": 0,
#   "taxNo": "",
#   "alerts": [],
#   "locationIds": [
#     771115
#   ],
#   "skills": [],
#   "orderId": 0
# }
#
# Input data size: 894 characters
# Time taken: 0.00 seconds

# %%
# Cell 6: Find relevant schema parts
start_time = time.time()

print("Searching for relevant schema parts...")
# Search for relevant chunks
relevant_chunks = vector_store.similarity_search(
    json.dumps(test_json),
    k=5,
    filter={"type": "chunk"}
)

print(f"\nFound {len(relevant_chunks)} relevant chunks")
print("\nMost relevant schema chunks:")
for i, doc in enumerate(relevant_chunks, 1):
    print(f"\nChunk {i}:")
    print(doc.page_content)
    print(f"Chunk {i} length: {len(doc.page_content)} characters")

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Searching for relevant schema parts...
#
# Found 5 relevant chunks
#
# Most relevant schema chunks:
#
# Chunk 1:
# CREATE TABLE `addresses` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `addressable_type` varchar(255) NOT NULL,
#   `addressable_id` bigint NOT NULL,
#   `address_line_1` varchar(255) DEFAULT null,
#   `address_line_2` varchar(255) DEFAULT null,
#   `address_line_3` varchar(255) DEFAULT null,
#   `town_city` varchar(255) DEFAULT null,
#   `state_county` varchar(255) DEFAULT null,
#   `postcode_zipcode` varchar(255) DEFAULT null,
#   `country` varchar(255) DEFAULT null,
#   `created_at` timestamp DEFAULT null,
# Chunk 1 length: 491 characters
#
# Chunk 2:
# `stripe_id` varchar(255) DEFAULT null,
#   `rehabmypatient_api_key` text,
#   `mailerlite_api_key` text,
#   `pm_type` varchar(255) DEFAULT null,
#   `pm_last_four` varchar(4) DEFAULT null,
#   `trial_ends_at` timestamp DEFAULT null,
#   `timezone` varchar(255) NOT NULL DEFAULT 'Europe/London',
#   `currency` varchar(255) NOT NULL DEFAULT 'GBP',
#   `disable_notifications` tinyint NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
# Chunk 2 length: 467 characters
#
# Chunk 3:
# CREATE TABLE `locations` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `practice_id` bigint NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `website` varchar(255) DEFAULT null,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `auto_email_form` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_portal_payments_active` tinyint(1) NOT NULL DEFAULT '0',
# Chunk 3 length: 468 characters
#
# Chunk 4:
# CREATE TABLE `users` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `title` ENUM ('Mr', 'Mrs', 'Miss', 'Ms', 'Mx', 'Sir', 'Dr', 'Lady', 'Lord', 'Master', 'Other') DEFAULT null,
#   `first_name` varchar(255) NOT NULL,
#   `last_name` varchar(255) NOT NULL,
#   `password` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `practice_id` bigint DEFAULT null,
#   `email_verified_at` timestamp DEFAULT null,
#   `remember_token` varchar(100) DEFAULT null,
#   `notes` text,
# Chunk 4 length: 466 characters
#
# Chunk 5:
# `referral_source` ENUM ('social_media', 'website', 'word_of_mouth', 'advert', 'google', 'other') DEFAULT null,
#   `cliniko_id` text,
#   `additional_fields` json DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `rehabmypatient_synced_at` datetime DEFAULT null,
#   `medical_alerts` json DEFAULT null
# );
# Chunk 5 length: 381 characters
#
# Time taken: 0.04 seconds

# %%
# Cell 7: Analyze input data
start_time = time.time()

print("Starting input analysis...")
analysis_prompt = f"""Analyze this JSON input and identify:
1. Missing required fields based on schema
2. Fields needing format conversion (especially dates and names)
3. Data quality issues or inconsistencies

Input JSON: {json.dumps(test_json, indent=2)}

Schema Context: {relevant_chunks[0].page_content}

Provide analysis in this format:
- Missing Fields: [list them]
- Format Conversions Needed: [field: required format]
- Quality Issues: [list any found]"""

analysis = llm.invoke(analysis_prompt)
print("\nInput Analysis Results:")
print(analysis)
print(f"\nAnalysis length: {len(analysis)} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting input analysis...
#
# Input Analysis Results:
# 1. Missing Fields:
#    - `addressable_type` (should be the type of object this address belongs to, e.g., "Person" or "Business")
#    - `created_at` (timestamp)
#
#   2. Format Conversions Needed:
#    - `fullAddress`: This field should ideally be broken down into separate fields like `address_line_1`, `address_line_2`, etc., according to the schema.
#    - `postCode`: Should be in a consistent format that matches the schema's `postcode_zipcode`.
#    - `gender`: The value "Male" does not match the expected gender values (either "Female" or "Male").
#    - `telephone`: This field should contain a valid phone number in an appropriate format.
#    - `contractNumber` and `regNumber`: These fields should contain numeric values.
#    - `commissionFlatRate` and `commissionPercent`: These fields should be numerical values, not strings.
#    - `timeSlot`: This field should be a numerical value representing the time slot.
#    - `taxNo`: This field should contain a valid tax number in an appropriate format.
#
#   3. Quality Issues:
#    - The `fullName` field contains "Miss" which is not consistent with the `gender` field value of "Male".
#    - The `locationName` field is different from the `defaultLocationId` and `locationIds`. It would be better if they were consistent.
#    - The `onlineGuid`, `online`, `fax`, `web`, and `orderId` fields are either empty or not used in this record, which may indicate inconsistencies or unnecessary fields.
#
# Analysis length: 1426 characters
# Time taken: 26.41 seconds

# %%
# Cell 8: Transform data
start_time = time.time()

print("Starting data transformation...")
transform_prompt = f"""Transform this JSON to match schema requirements:

Input JSON: {json.dumps(test_json, indent=2)}

Relevant Schema Context: {relevant_chunks[0].page_content}

Analysis Results: {analysis}

Requirements:
1. Follow schema data types exactly
2. Handle missing fields appropriately
3. Convert date formats to ISO (YYYY-MM-DD)
4. Split name fields if needed
5. Ensure all required fields are present

Return valid JSON only without any explanation."""

print("Sending transformation prompt...")
transformed_result = llm.invoke(transform_prompt)
print(f"Received response length: {len(transformed_result)} characters")

# Try to parse the result as JSON
try:
    transformed_data = json.loads(transformed_result)
    print("\nSuccessfully parsed transformed data:")
    print(json.dumps(transformed_data, indent=2))
    print(f"\nNumber of fields in output: {len(transformed_data.keys())}")
    print("Output fields:", list(transformed_data.keys()))
except json.JSONDecodeError as e:
    print("\nWarning: Output was not valid JSON")
    print("Error:", str(e))
    print("\nRaw output:")
    print(transformed_result)

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting data transformation...
# Sending transformation prompt...
# Received response length: 1279 characters
#
# Warning: Output was not valid JSON
# Error: Expecting property name enclosed in double quotes: line 18 column 27 (char 546)
#
# Raw output:
#  {
#       "id": 678669,
#       "addressable_type": "Person",
#       "addressable_id": 678669,
#       "address_line_1": "125 Jackson Ranch",
#       "address_line_2": "",
#       "address_line_3": "",
#       "address_line_4": "",
#       "address_line_5": "",
#       "town_city": "Port Damienberg",
#       "state_county": "Lancashire",
#       "postcode_zipcode": "TS24 7QA",
#       "country": "Scotland",
#       "created_at": "YYYY-MM-DD HH:mm:ss",
#       "fullName": "Lizzie Brown",
#       "forename": "Lizzie",
#       "surname": "Brown",
#       "gender": "Female", // Corrected based on fullName field
#       "locationName": 771115, // Assuming locationName is the id of the location
#       "title": "Miss",
#       "telephone": "+44-07608-506942", // Formatted phone number
#       "email": "uhughes@example.net",
#       "fax": "",
#       "web": "",
#       "online": true,
#       "status": 1,
#       "type": "Acupuncturist",
#       "contractNumber": 0, // Assuming these fields are not needed
#       "regNumber": 0, // Assuming these fields are not needed
#       "commissionFlatRate": 0,
#       "commissionPercent": 0,
#       "employmentStatus": "Acupuncturist",
#       "timeSlot": 0,
#       "taxNo": "",
#       "alerts": [],
#       "locationIds": [
#         771115
#       ],
#       "skills": [],
#       "orderId": 0
#    }
#
# Time taken: 34.71 seconds

# %%
start_time = time.time()

print("Searching for relevant schema parts...")
results = vector_store.similarity_search_with_score(
    json.dumps(test_json),
    k=10,
    filter={"type": "chunk"}
)

relevant_chunks = [doc for doc, score in results if score < 0.8]

print(f"\nFound {len(relevant_chunks)} relevant chunks")
print("\nMost relevant chunks with scores:")
for i, (doc, score) in enumerate(results, 1):
    print(f"\nChunk {i}:")
    if 'CREATE TABLE' in doc.page_content:
        table_name = doc.page_content.split('`')[1]
        print(f"Table: {table_name}")
        print(f"Similarity Score: {score:.4f}")
    print(doc.page_content)
    print(f"Length: {len(doc.page_content)} characters")

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Searching for relevant schema parts...
#
# Found 0 relevant chunks
#
# Most relevant chunks with scores:
#
# Chunk 1:
# Table: addresses
# Similarity Score: 1.1762
# CREATE TABLE `addresses` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `addressable_type` varchar(255) NOT NULL,
#   `addressable_id` bigint NOT NULL,
#   `address_line_1` varchar(255) DEFAULT null,
#   `address_line_2` varchar(255) DEFAULT null,
#   `address_line_3` varchar(255) DEFAULT null,
#   `town_city` varchar(255) DEFAULT null,
#   `state_county` varchar(255) DEFAULT null,
#   `postcode_zipcode` varchar(255) DEFAULT null,
#   `country` varchar(255) DEFAULT null,
#   `created_at` timestamp DEFAULT null,
# Length: 491 characters
#
# Chunk 2:
# `stripe_id` varchar(255) DEFAULT null,
#   `rehabmypatient_api_key` text,
#   `mailerlite_api_key` text,
#   `pm_type` varchar(255) DEFAULT null,
#   `pm_last_four` varchar(4) DEFAULT null,
#   `trial_ends_at` timestamp DEFAULT null,
#   `timezone` varchar(255) NOT NULL DEFAULT 'Europe/London',
#   `currency` varchar(255) NOT NULL DEFAULT 'GBP',
#   `disable_notifications` tinyint NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
# Length: 467 characters
#
# Chunk 3:
# Table: locations
# Similarity Score: 1.3060
# CREATE TABLE `locations` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `practice_id` bigint NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `website` varchar(255) DEFAULT null,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `auto_email_form` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_portal_payments_active` tinyint(1) NOT NULL DEFAULT '0',
# Length: 468 characters
#
# Chunk 4:
# Table: users
# Similarity Score: 1.3250
# CREATE TABLE `users` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `title` ENUM ('Mr', 'Mrs', 'Miss', 'Ms', 'Mx', 'Sir', 'Dr', 'Lady', 'Lord', 'Master', 'Other') DEFAULT null,
#   `first_name` varchar(255) NOT NULL,
#   `last_name` varchar(255) NOT NULL,
#   `password` varchar(255) DEFAULT null,
#   `email` varchar(255) DEFAULT null,
#   `practice_id` bigint DEFAULT null,
#   `email_verified_at` timestamp DEFAULT null,
#   `remember_token` varchar(100) DEFAULT null,
#   `notes` text,
# Length: 466 characters
#
# Chunk 5:
# `referral_source` ENUM ('social_media', 'website', 'word_of_mouth', 'advert', 'google', 'other') DEFAULT null,
#   `cliniko_id` text,
#   `additional_fields` json DEFAULT null,
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `rehabmypatient_synced_at` datetime DEFAULT null,
#   `medical_alerts` json DEFAULT null
# );
# Length: 381 characters
#
# Chunk 6:
# Table: practices
# Similarity Score: 1.3778
# CREATE TABLE `practices` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `email` varchar(255) DEFAULT null,
#   `booking_portal_active` tinyint(1) NOT NULL DEFAULT '0',
#   `booking_reminders_enabled` tinyint(1) NOT NULL DEFAULT '1',
#   `sms_enabled` tinyint(1) NOT NULL DEFAULT '0',
#   `sms_from_name` varchar(255) DEFAULT null,
#   `connected_stripe_account_id` varchar(255) DEFAULT null,
#   `stripe_id` varchar(255) DEFAULT null,
# Length: 484 characters
#
# Chunk 7:
# Table: media
# Similarity Score: 1.3967
# CREATE TABLE `media` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `model_type` varchar(255) NOT NULL,
#   `model_id` bigint NOT NULL,
#   `collection_name` varchar(255) NOT NULL,
#   `name` varchar(255) NOT NULL,
#   `file_name` varchar(255) NOT NULL,
#   `mime_type` varchar(255) DEFAULT null,
#   `disk` varchar(255) NOT NULL,
#   `size` bigint NOT NULL,
#   `manipulations` json NOT NULL,
#   `custom_properties` json NOT NULL,
#   `responsive_images` json NOT NULL,
#   `order_column` int DEFAULT null,
# Length: 479 characters
#
# Chunk 8:
# Table: services
# Similarity Score: 1.4003
# CREATE TABLE `services` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `parent_service_id` bigint NOT NULL,
#   `appointment_form_id` bigint DEFAULT null,
#   `service_information_link` int DEFAULT null,
#   `send_form_email` tinyint(1) DEFAULT null,
#   `name` varchar(255) NOT NULL,
#   `description` text,
#   `time_required_minutes` int DEFAULT null,
#   `start_minutes_past_hour` int DEFAULT null,
#   `price` int DEFAULT null,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
# Length: 472 characters
#
# Chunk 9:
# Table: practitioner_details
# Similarity Score: 1.4196
# CREATE TABLE `practitioner_details` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `user_id` bigint NOT NULL,
#   `phone_number` varchar(255) DEFAULT null,
#   `position` varchar(255) DEFAULT null,
#   `working_hours` json DEFAULT null,
#   `biography` text,
#   `visible_on_booking_portal` tinyint(1) NOT NULL DEFAULT '0',
#   `created_at` timestamp DEFAULT null,
#   `updated_at` timestamp DEFAULT null,
#   `deleted_at` timestamp DEFAULT null,
#   `cliniko_id` text
# );
# Length: 446 characters
#
# Chunk 10:
# Table: patient_treatment_plans
# Similarity Score: 1.4269
# CREATE TABLE `patient_treatment_plans` (
#   `id` bigint PRIMARY KEY NOT NULL,
#   `unique_id` varchar(255) NOT NULL,
#   `practitioner_id` bigint NOT NULL,
#   `patient_id` bigint NOT NULL,
#   `location_id` bigint NOT NULL,
#   `appointment_id` bigint DEFAULT null,
#   `description` longtext,
#   `message` longtext,
#   `plans` json DEFAULT null,
#   `default_plan` bigint DEFAULT null,
#   `selected_plan` bigint DEFAULT null,
#   `patient_replay` longtext,
#   `status` varchar(255) DEFAULT null,
# Length: 476 characters
#
# Time taken: 0.04 seconds

# %%
start_time = time.time()

print("Starting input analysis...")
analysis_prompt = f"""CHECK THESE STEPS EXACTLY:

1. Find a CREATE TABLE statement in the schema that starts with "CREATE TABLE `"
2. Only proceed if you find an exact match - do not invent or modify tables
3. Copy that exact CREATE TABLE statement as proof
4. Match input JSON fields to the actual columns in that CREATE TABLE statement

Input JSON: {json.dumps(test_json, indent=2)}

Available Schema:
{chr(10).join(f"Table {i+1}: {chunk.page_content}" for i, chunk in enumerate(relevant_chunks))}

Steps required in your response:
1. Quote the exact CREATE TABLE statement you found (must exist in schema)
2. Show which input fields match to which actual table columns
3. List which schema columns need NULL/defaults
4. If you cannot find a real CREATE TABLE statement, say "No matching table found"
"""

analysis = llm.invoke(analysis_prompt)
print("\nAnalysis Results:")
print(analysis)
print(f"\nAnalysis length: {len(analysis)} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting input analysis...
#
# Analysis Results:
# 1. Quote the exact CREATE TABLE statement I found (must exist in schema):
#
# I'm unable to provide an exact `CREATE TABLE` statement as the provided schema does not contain any table that starts with "CREATE TABLE `". It seems like you might have missed or omitted the relevant table creation statements.
#
#   2. Show which input fields match to which actual table columns:
#
# Here is a suggested mapping between the input JSON fields and potential table columns based on the schema provided:
#
# - id (input) -> id (schema, if it exists)
# - fullName (input) -> name (schema, assuming there's a 'name' column in the table)
# - name (input) -> name (schema, assuming there's a 'name' column in the table)
# - code (input) -> code (schema, if it exists)
# - fullAddress (input) -> address (schema, assuming there's an 'address' column in the table)
# - locationName (input) -> location_name (schema, assuming there's a 'location_name' column in the table)
# - title (input) -> title (schema, if it exists)
# - forename (input) -> first_name (schema, assuming there's a 'first_name' column in the table)
# - surname (input) -> last_name (schema, assuming there's a 'last_name' column in the table)
# - gender (input) -> gender (schema, if it exists)
# - addressLine1 (input) -> address_line1 (schema, assuming there's an 'address_line1' column in the table)
# - addressLine2 (input) -> address_line2 (schema, assuming there's an 'address_line2' column in the table)
# - addressLine3 (input) -> address_line3 (schema, assuming there's an 'address_line3' column in the table)
# - addressLine4 (input) -> address_line4 (schema, assuming there's an 'address_line4' column in the table)
# - addressLine5 (input) -> address_line5 (schema, assuming there's an 'address_line5' column in the table)
# - postCode (input) -> postcode (schema, assuming there's a 'postcode' column in the table)
# - telephone (input) -> phone (schema, if it exists)
# - mobile (input) -> mobile (schema, assuming there's a 'mobile' column in the table)
# - email (input) -> email (schema, if it exists)
# - fax (input) -> fax (schema, if it exists)
# - web (input) -> website (schema, if it exists)
# - online (input) -> is_online (schema, assuming there's an 'is_online' column in the table)
# - status (input) -> status (schema, if it exists)
# - type (input) -> profession (schema, assuming there's a 'profession' column in the table)
# - contractNumber (input) -> contract_number (schema, if it exists)
# - onlineGuid (input) -> online_guid (schema, assuming there's an 'online_guid' column in the table)
# - defaultLocationId (input) -> default_location_id (schema, assuming there's a 'default_location_id' column in the table)
# - serviceTypeId (input) -> service_type_id (schema, assuming there's a 'service_type_id' column in the table)
# - regNumber (input) -> reg_number (schema, if it exists)
# - commissionFlatRate (input) -> commission_flat_rate (schema, assuming there's a 'commission_flat_rate' column in the table)
# - commissionPercent (input) -> commission_percent (schema, assuming there's a 'commission_percent' column in the table)
# - employmentStatus (input) -> employment_status (schema, assuming there's an 'employment_status' column in the table)
# - timeSlot (input) -> time_slot (schema, if it exists)
# - taxNo (input) -> tax_no (schema, if it exists)
# - alerts (input) -> alerts (schema, assuming there's an 'alerts' column in the table, but this might be a separate table or a JSON field)
# - locationIds (input) -> location_ids (schema, assuming there's a 'location_ids' column in the table, but this might be a separate table or a JSON field)
# - skills (input) -> skills (schema, assuming there's a 'skills' column in the table, but this might be a separate table or a JSON field)
# - orderId (input) -> order_id (schema, if it exists)
#
#   3. List which schema columns need NULL/defaults:
#
# Based on the suggested mapping above, here are the potential schema columns that may require NULL or default values:
#
# - id (if it doesn't exist in the table)
# - code (if it doesn't exist in the table)
# - phone (if it doesn't exist in the table)
# - is_online (if it doesn't exist in the table, but you can assume a default value like 0 or false)
# - profession (if it doesn't exist in the table)
# - contract_number (if it doesn't exist in the table)
# - online_guid (if it doesn't exist in the table)
# - default_location_id (if it doesn't exist in the table, but you can assume a default value like 0 or null)
# - service_type_id (if it doesn't exist in the table, but you can assume a default value like 0 or null)
# - reg_number (if it doesn't exist in the table)
# - commission_flat_rate (if it doesn't exist in the table, but you can assume a default value like 0)
# - commission_percent (if it doesn't exist in the table, but you can assume a default value like 0)
# - employment_status (if it doesn't exist in the table, but you can assume a default value like 'Acupuncturist')
# - time_slot (if it doesn't exist in the table, but you can assume a default value like 0)
# - tax_no (if it doesn't exist in the table)
# - order_id (if it doesn't exist in the table)
#
#   4. Create SQL statements for each table:
#
# Assuming we have three tables: `Person`, `Address`, and `Profession`. Here are the SQL statements for each table based on the suggested mapping above:
#
# ```sql
# CREATE TABLE IF NOT EXISTS Person (
#     id INT PRIMARY KEY DEFAULT 0,
#     code VARCHAR(255) DEFAULT NULL,
#     first_name VARCHAR(255) NOT NULL,
#     last_name VARCHAR(255) NOT NULL,
#     email VARCHAR(255) DEFAULT NULL,
#     phone VARCHAR(255) DEFAULT NULL,
#     is_online TINYINT DEFAULT 0,
#     profession_id INT DEFAULT 0,
#     contract_number VARCHAR(255) DEFAULT NULL,
#     online_guid VARCHAR(255) DEFAULT NULL,
#     default_location_id INT DEFAULT 0,
#     service_type_id INT DEFAULT 0,
#     reg_number VARCHAR(255) DEFAULT NULL,
#     commission_flat_rate DECIMAL(10,2) DEFAULT 0,
#     commission_percent DECIMAL(10,2) DEFAULT 0,
#     employment_status VARCHAR(255) DEFAULT 'Acupuncturist',
#     time_slot INT DEFAULT 0,
#     tax_no VARCHAR(255) DEFAULT NULL,
#     alerts JSON DEFAULT '{}',
#     location_ids JSON DEFAULT '[]',
#     skills JSON DEFAULT '[]',
#     order_id INT DEFAULT 0
# );
#
# CREATE TABLE IF NOT EXISTS Address (
#     id INT PRIMARY KEY AUTO_INCREMENT,
#     person_id INT,
#     address1 VARCHAR(255) NOT NULL,
#     address2 VARCHAR(255),
#     city VARCHAR(255) NOT NULL,
#     state VARCHAR(255),
#     postcode VARCHAR(255) NOT NULL,
#     country VARCHAR(255) NOT NULL,
#     FOREIGN KEY (person_id) REFERENCES Person(id)
# );
#
# CREATE TABLE IF NOT EXISTS Profession (
#     id INT PRIMARY KEY AUTO_INCREMENT,
#     name VARCHAR(255) NOT NULL,
#     description TEXT,
#     FOREIGN KEY (person_id) REFERENCES Person(id)
# );
# ```
#
# Analysis length: 6665 characters
# Time taken: 121.92 seconds

# %%
start_time = time.time()

print("Starting input analysis...")
analysis_prompt = f"""You are an AI Data engineer and you are required to match input json to your company's schema. It is extremely important to not infer a table or table name based on input json data, only use the exact names/titles of the tables present in schema. Do not add any fields/column in input json that are not in the schema into the output, the goal is tho match the schema exactly to enable easy data entry and onboarding.
For all future outputs, only use the exact names/titles of the fields present in schema, if a field in input is not present in schema, forget about it as we want to match the schema exactly to enable easy data entry and onboarding. 

Analyze this JSON input against ALL relevant schema tables and prove that the name of the table from the schema was named as is, by mentioning the position of the table in the schema to back up your claim:

Input JSON: {json.dumps(test_json, indent=2)}

Schema Tables:
{chr(10).join(f"Table {i+1}: {chunk.page_content}" for i, chunk in enumerate(relevant_chunks))}



DO:
identify all the tables present in the relevant schema chunk that are relevant to the input json for transformation. It is extremely important to not infer a table or table name based on input json data, only use the exact names/titles of the tables present in schema

state the proof that the name of the table from the schema was named as is, by mentioning the position of the table in the schema to back up your claim, state the line number of said table in schema


"""

analysis = llm.invoke(analysis_prompt)
print("\nAnalysis Results:")
print(analysis)
print(f"\nAnalysis length: {len(analysis)} characters")
print(f"Time taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting input analysis...
#
# Analysis Results:
#  Based on the provided Input JSON and Schema Tables, I can identify three tables relevant to the data: "Employee", "Location", and "Service".
#
#    Here's the proof that the names of these tables from the schema were named as is, by mentioning the line number of said tables in schema:
#
#    - The "Employee" table is present on line 10 of the Schema Tables. The JSON data contains fields such as "id", "fullName", "name", "code", "fullAddress", "locationName", "title", "forename", "surname", "gender", "addressLine1", "addressLine2", "addressLine3", "addressLine4", "addressLine5", "postCode", "telephone", "mobile", "email", "fax", "web", "online", "status", and "employmentStatus". These fields match the column names in the "Employee" table of the schema.
#
#    - The "Location" table is present on line 15 of the Schema Tables. The JSON data contains fields such as "locationName", "addressLine1", "addressLine2", "addressLine3", "addressLine4", "addressLine5", and "postCode". These fields match the column names in the "Location" table of the schema.
#
#    - The "Service" table is present on line 19 of the Schema Tables. The JSON data contains fields such as "type", "contractNumber", "onlineGuid", "defaultLocationId", "serviceTypeId", and "timeSlot". These fields match the column names in the "Service" table of the schema.
#
#    Additionally, the JSON data does not contain any fields that are not present in the schema for these tables, ensuring easy data entry and onboarding as required.
#
# Analysis length: 1494 characters
# Time taken: 22.37 seconds

# %%
start_time = time.time()

print("Starting data transformation...")
transform_prompt = f"""Transform this JSON to match schema requirements:

Input JSON: {json.dumps(test_json, indent=2)}

Schema Requirements:
{chr(10).join(f"Table {i+1}: {chunk.page_content}" for i, chunk in enumerate(relevant_chunks))}

Analysis Results: {analysis}

Return JSON with field names of the schema as keys and transformed data as values. The keys should match exactly to the column/field names in the schema and any field given in input json that is not a field in the schema shoud be dropped. All fields in the schema should be present and missing fields should be filled with null. Do not add any new fields or tables. Remove any field or columns in the input json that is not in the schema especially fields about names."""

print("Sending transformation prompt...")
transformed_result = llm.invoke(transform_prompt)
print(f"Received response length: {len(transformed_result)} characters")

try:
    transformed_data = json.loads(transformed_result)
    print("\nTransformed data:")
    print(json.dumps(transformed_data, indent=2))
    print(f"\nTables transformed: {list(transformed_data.keys())}")
except json.JSONDecodeError as e:
    print("\nWarning: Invalid JSON output")
    print(f"Error: {str(e)}")
    print("\nRaw output:")
    print(transformed_result)

print(f"\nTime taken: {time.time() - start_time:.2f} seconds")
# Out:
# Starting data transformation...
# Sending transformation prompt...
# Received response length: 1601 characters
#
# Warning: Invalid JSON output
# Error: Expecting value: line 1 column 2 (char 1)
#
# Raw output:
#  Here's the transformed JSON based on the schema requirements:
#
# ```JSON
# {
#   "EmployeeId": null,
#   "FirstName": "Lizzie",
#   "LastName": "Brown",
#   "Gender": "Female", // Corrected from "Male" to match the title "Miss"
#   "LocationId": 771115,
#   "ServiceProviderId": null,
#   "ContactId": null,
#   "Address_Line1": "125 Jackson Ranch",
#   "Address_Line2": "",
#   "Address_Line3": "",
#   "Address_Line4": "",
#   "Address_Line5": "",
#   "PostCode": "TS24 7QA",
#   "Telephone": "", // This field might not be acceptable depending on the business rules
#   "Mobile": "07608 506942",
#   "Email": "uhughes@example.net",
#   "Fax": "",
#   "Web": "",
#   "Online": true,
#   "Status": 1,
#   "Type": "Acupuncturist",
#   "ContractNumber": "", // This field might not be acceptable depending on the business rules
#   "RegNumber": "", // This field might not be acceptable depending on the business rules
#   "CommissionFlatRate": 0,
#   "CommissionPercent": 0,
#   "EmploymentStatus": "Acupuncturist",
#   "TimeSlot": 0, // This value should be verified for accuracy or replaced with a valid value if any specific values are required
#   "TaxNo": "",
#   "Alerts": [],
#   "LocationIds": [
#     771115
#   ],
#   "Skills": [],
#   "ServiceTypeId": 1,
#   "OrderId": 0
# }
# ```
#
# This JSON now matches the schema requirements with field names that exactly match the column/field names in the schema. Any fields not present in the schema have been removed or filled with null values. The gender field has been corrected to match the title "Miss". The timeSlot field should be verified for accuracy or replaced with a valid value if any specific values are required.
#
# Time taken: 34.52 seconds
